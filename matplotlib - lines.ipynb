# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.plot(x, y, marker='o', linestyle='-', color='r', label="Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Simple Line Plot")
plt.legend()
plt.show()

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis
# , y axis and a title

# %%
x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y,marker = 'o',linestyle = '-',color = 'g',label = 'line plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line graph')
plt.legend()
plt.show()

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.

# %%
data = np.loadtxt(r"C:/Users/Leon/Downloads/coord.txt") 
x, y = data[:, 0], data[:, 1] 

plt.plot(x, y, marker='o', linestyle='-', color='y', label="line plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Plot from textfile")
plt.legend()
plt.show()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016

# %%
df = pd.read_csv("C:/Users/Leon/Downloads/q4.csv")

plt.figure(figsize=(10, 5))
plt.plot(df["Date"], df["Open"], marker='o', linestyle='-', label="Open Price", color='b')
plt.plot(df["Date"], df["High"], marker='o', linestyle='-', label="High Price", color='g')
plt.plot(df["Date"], df["Low"], marker='o', linestyle='-', label="Low Price", color='r')
plt.plot(df["Date"], df["Close"], marker='o', linestyle='-', label="Close Price", color='y')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Alphabet Inc. Financial Data (Oct 3 - Oct 7, 2016)")
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each
# line

# %%
x = [1,2,3,4,5]
y = [30,10,20,90,40]
z = [15,30,40,20,50]
plt.plot(x,y,marker = 'o',linestyle = '--',color = 'r',label = 'First line')
plt.plot(x,z,marker = 'o',linestyle = '--',color = 'b',label = 'Second line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()
plt.show()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x = [1,2,3,4,5]
y = [30,10,20,90,40]
z = [15,30,40,20,50]
plt.plot(x,y,marker = 'o',linestyle = '-',color = 'r',label = 'First line',linewidth = 2)
plt.plot(x,z,marker = 'o',linestyle = '-',color = 'b',label = 'Second line',linewidth = 4)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()
plt.show()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
x = [1,2,3,4,5]
y = [30,10,20,90,40]
z = [15,30,40,20,50]
plt.plot(x,y,marker = 'o',linestyle = '--',color = 'r',label = 'First line')
plt.plot(x,z,marker = 'o',linestyle = '-',color = 'b',label = 'Second line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()
plt.show()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x = [1,2,3,4,5]
y = [30,10,20,90,40]
z = [15,30,40,20,50]
plt.plot(x,y,marker = 'o',linestyle = '-',color = 'r',label = 'First line')
plt.plot(x,z,marker = '^',linestyle = '-',color = 'b',label = 'Second line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()
plt.show()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
x = [1, 2, 3, 4, 5]
y = [30, 10, 20, 90, 40]
z = [15, 30, 40, 20, 50]

fig, ax = plt.subplots()
ax.plot(x, y, marker='o', linestyle='-', color='r', label='First line')
ax.plot(x, z, marker='^', linestyle='-', color='b', label='Second line')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()

print("Current X-axis limits:", ax.get_xlim())
print("Current Y-axis limits:", ax.get_ylim())

plt.show()
# Out:
# Current X-axis limits: (np.float64(0.8), np.float64(5.2))
# Current Y-axis limits: (np.float64(6.0), np.float64(94.0))

# %% [markdown]
# 10.  Write a Python program to plot quantities which have an x and y position.

# %%
x = [1,2,3,4,5]
y = [30,10,20,90,40]
z = [15,30,40,20,50]
plt.plot(x,y,marker = 'o',linestyle = '-',color = 'r',label = 'First line')
plt.plot(x,z,marker = '^',linestyle = '-',color = 'b',label = 'Second line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple line graph')
plt.legend()
plt.show()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command
# using arrays.

# %%
x = [1, 2, 3, 4, 5]
y = [30, 10, 20, 90, 40]
z = [15, 35, 25, 50, 30]

plt.plot(x, y, 'r-o', x, z, 'b--s', label='Line 1, Line 2')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Two Lines with Different Styles')
plt.legend()
plt.show()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
x = [1, 2, 3, 4, 5]
y = [30, 10, 20, 90, 40]
z = [15, 35, 25, 50, 30]

plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(x, y, 'r-o', x, z, 'b--s')
plt.title('Line Chart')

plt.subplot(2, 2, 2)
plt.bar(x, y, color='r', alpha=0.7)
plt.bar(x, z, color='b', alpha=0.7)
plt.title('Bar Chart')

plt.subplot(2, 2, 3)
plt.scatter(x, y, color='r')
plt.scatter(x, z, color='b')
plt.title('Scatter Plot')

plt.subplot(2, 2, 4)
plt.pie(y, labels=x, autopct='%1.1f%%', colors=['red', 'blue', 'green', 'yellow', 'purple'])
plt.title('Pie Chart')

plt.tight_layout()
plt.show()

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016

# %%
df = pd.read_csv("C:/Users/Leon/Downloads/Date.csv")

plt.figure(figsize=(8, 5))
plt.plot(df['Date'], df['Close'], marker='o', linestyle='-', color='green', label='Closing Price')

plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.title('Alphabet Inc. Closing Prices (Oct 3-7, 2016)')
plt.xticks(df['Date'], rotation=45)
plt.grid(True, linestyle='--', linewidth=0.5, color='blue')
plt.legend()
plt.show()

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
# off ticks.

# %%
df = pd.read_csv("C:/Users/Leon/Downloads/Date.csv")

plt.figure(figsize=(8, 5))
plt.plot(df['Date'], df['Close'], marker='o', linestyle='-', color='green', label='Closing Price')

plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.title('Alphabet Inc. Closing Prices')
plt.xticks(df['Date'], rotation=45)

plt.grid(True, which='major', linestyle='-', linewidth=0.8, color='blue')
plt.grid(True, which='minor', linestyle='--', linewidth=0.5, color='gray')
plt.minorticks_on()

plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False)

plt.legend()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 15. Write a Python program to create multiple plots.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axes = plt.subplots(2, 1, figsize=(8, 10))

axes[0].plot(x, y1, marker='o', linestyle='-', color='green', label='Sine Wave')
axes[0].set_xlabel('X values')
axes[0].set_ylabel('Sine')
axes[0].set_title('Sine Wave')
axes[0].grid(True)
axes[0].legend()

axes[1].plot(x, y2, marker='s', linestyle='-', color='red', label='Cosine Wave')
axes[1].set_xlabel('X values')
axes[1].set_ylabel('Cosine')
axes[1].set_title('Cosine Wave')
axes[1].grid(True)
axes[1].legend()

plt.tight_layout()
plt.show()
